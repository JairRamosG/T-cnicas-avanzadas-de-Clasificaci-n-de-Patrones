# %%
from sklearn.datasets import fetch_openml
import pandas as pd
from sklearn.model_selection import train_test_split
import math
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE

# %%
X, y = fetch_openml(
    data_id=1104,          # ID de Leukemia
    return_X_y=True,
    as_frame=True
)

print("shape Características :", X.shape)
print("shape Etiquetas       :", y.shape)

print("Tipo X :", type(X))
print("Tipo y :", type(y))
# Out:
# shape Características : (72, 7129)
# shape Etiquetas       : (72,)
# Tipo X : <class 'pandas.core.frame.DataFrame'>
# Tipo y : <class 'pandas.core.series.Series'>

# %%
X.head()
# Out:
#    AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioB-3_at  AFFX-BioC-5_at  \
# 0            -214            -153             -58              88
# 1            -139             -73              -1             283
# 2             -76             -49            -307             309
# 3            -135            -114             265              12
# 4            -106            -125             -76             168
#
#    AFFX-BioC-3_at  AFFX-BioDn-5_at  AFFX-BioDn-3_at  AFFX-CreX-5_at  \
# 0            -295             -558              199            -176
# 1            -264             -400             -330            -168
# 2            -376             -650               33            -367
# 3            -419             -585              158            -253
# 4            -230             -284                4            -122
#
#    AFFX-CreX-3_at  AFFX-BioB-5_st  ...  U48730_at  U58516_at  U73738_at  \
# 0             252             206  ...        185        511       -125
# 1             101              74  ...        169        837        -36
# 2             206            -215  ...        315       1199         33
# 3              49              31  ...        240        835        218
# 4              70             252  ...        156        649         57
#
#    X06956_at  X16699_at  X83863_at  Z17240_at  L49218_f_at  M71243_f_at  \
# 0        389        -37        793        329           36          191
# 1        442        -17        782        295           11           76
# 2        168         52       1138        777           41          228
# 3        174       -110        627        170          -50          126
# 4        504        -26        250        314           14           56
#
#    Z78285_f_at
# 0          -37
# 1          -14
# 2          -41
# 3          -91
# 4          -25
#
# [5 rows x 7129 columns]

# %% [markdown]
# ### Mapear etiquetas

# %%
y = y.map({'AML': 0, 'ALL': 1})
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: CLASS, dtype: category
# Categories (2, int64): [1, 0]

# %% [markdown]
# ### Normalizar las Características

# %%
escaler = MinMaxScaler()
X_scaled = pd.DataFrame(escaler.fit_transform(X), columns=X.columns)

# %%
X_scaled.head()
# Out:
#    AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioB-3_at  AFFX-BioC-5_at  \
# 0        0.466192        0.729730        0.487535        0.265525
# 1        0.599644        0.884170        0.566482        0.683084
# 2        0.711744        0.930502        0.142659        0.738758
# 3        0.606762        0.805019        0.934903        0.102784
# 4        0.658363        0.783784        0.462604        0.436831
#
#    AFFX-BioC-3_at  AFFX-BioDn-5_at  AFFX-BioDn-3_at  AFFX-CreX-5_at  \
# 0        0.375573         0.366279         0.708071        0.634956
# 1        0.422901         0.595930         0.405266        0.652655
# 2        0.251908         0.232558         0.613051        0.212389
# 3        0.186260         0.327035         0.684602        0.464602
# 4        0.474809         0.764535         0.596451        0.754425
#
#    AFFX-CreX-3_at  AFFX-BioB-5_st  ...  U48730_at  U58516_at  U73738_at  \
# 0        0.928074        0.500743  ...   0.515924   0.268886   0.331384
# 1        0.577726        0.402675  ...   0.481953   0.477593   0.504873
# 2        0.821346        0.187964  ...   0.791932   0.709347   0.639376
# 3        0.457077        0.370728  ...   0.632696   0.476312   1.000000
# 4        0.505800        0.534918  ...   0.454352   0.357234   0.686160
#
#    X06956_at  X16699_at  X83863_at  Z17240_at  L49218_f_at  M71243_f_at  \
# 0   0.161897   0.672794   0.322954   0.322328     0.754658     0.079423
# 1   0.182673   0.746324   0.318060   0.292789     0.677019     0.044158
# 2   0.075265   1.000000   0.476423   0.711555     0.770186     0.090770
# 3   0.077617   0.404412   0.249110   0.184188     0.487578     0.059491
# 4   0.206978   0.713235   0.081406   0.309296     0.686335     0.038025
#
#    Z78285_f_at
# 0     0.570896
# 1     0.656716
# 2     0.555970
# 3     0.369403
# 4     0.615672
#
# [5 rows x 7129 columns]

# %% [markdown]
# ### Partición fija 80 20 para el df

# %%
df = pd.concat([X_scaled, y], axis = 1)
df = df.sample(frac = 1, random_state=42).reset_index(drop = True)
df.head()
# Out:
#    AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioB-3_at  AFFX-BioC-5_at  \
# 0        0.658363        0.783784        0.462604        0.436831
# 1        0.560498        0.610039        0.504155        0.389722
# 2        0.768683        0.926641        0.706371        0.520343
# 3        0.466192        0.729730        0.487535        0.265525
# 4        0.873665        0.805019        0.570637        0.490364
#
#    AFFX-BioC-3_at  AFFX-BioDn-5_at  AFFX-BioDn-3_at  AFFX-CreX-5_at  \
# 0        0.474809         0.764535         0.596451        0.754425
# 1        0.563359         0.311047         0.524327        0.269912
# 2        0.603053         0.856105         0.641671        0.586283
# 3        0.375573         0.366279         0.708071        0.634956
# 4        0.748092         0.952035         0.610761        0.792035
#
#    AFFX-CreX-3_at  AFFX-BioB-5_st  ...  U58516_at  U73738_at  X06956_at  \
# 0        0.505800        0.534918  ...   0.357234   0.686160   0.206978
# 1        0.740139        0.238484  ...   0.350832   0.522417   0.224226
# 2        0.422274        0.332838  ...   0.195903   0.481481   0.769502
# 3        0.928074        0.500743  ...   0.268886   0.331384   0.161897
# 4        0.440835        0.736999  ...   0.256722   0.680312   0.117993
#
#    X16699_at  X83863_at  Z17240_at  L49218_f_at  M71243_f_at  Z78285_f_at  \
# 0   0.713235   0.081406   0.309296     0.686335     0.038025     0.615672
# 1   0.665441   0.330071   0.423110     0.636646     0.085250     0.768657
# 2   0.742647   0.209520   0.114683     0.487578     0.122968     0.619403
# 3   0.672794   0.322954   0.322328     0.754658     0.079423     0.570896
# 4   0.761029   0.094306   0.080799     0.661491     0.782582     0.701493
#
#    CLASS
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#
# [5 rows x 7130 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42)

print("shape X_train :", X_train.shape)
print("shape y_train :", y_train.shape)    
print("shape X_test  :", X_test.shape)
print("shape y_test  :", y_test.shape)
# Out:
# shape X_train : (57, 7129)
# shape y_train : (57,)
# shape X_test  : (15, 7129)
# shape y_test  : (15,)

# %%
print("shape y_train :", y_train.value_counts())
print('')
print("shape y_test  :", y_test.value_counts())
# Out:
# shape y_train : CLASS
# 1    39
# 0    39
# Name: count, dtype: int64
#
# shape y_test  : CLASS
# 1    10
# 0     5
# Name: count, dtype: int64

# %%
print(f'IR entrenamiento : {y_train.value_counts()[0] / y_train.value_counts()[1]:.2f}')
print(f'IR prueba        : {y_test.value_counts()[0] / y_test.value_counts()[1]:.2f}')
# Out:
# IR entrenamiento : 1.00
# IR prueba        : 0.50

# %% [markdown]
# ### Crear df_train y df_test

# %%
df_train = pd.concat([X_train, y_train], axis=1)
df_test = pd.concat([X_test, y_test], axis=1)

# %% [markdown]
# ### Balancear el df de entrenamiento
#
# * Este dataset no es necesario

# %%
df_train['CLASS'].value_counts()
# Out:
# CLASS
# 1    39
# 0    39
# Name: count, dtype: int64

# %%
X_train = df_train.drop(columns = ['CLASS'])
y_train = df_train['CLASS']

smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

print(f'shape antes de SMOTE: {X_train.shape}')
print(f'shape despueés de SMOTE: {X_train_smote.shape}')

y_train_smote.value_counts()
# Out:
# shape antes de SMOTE: (78, 7129)
# shape despueés de SMOTE: (78, 7129)
# CLASS
# 1    39
# 0    39
# Name: count, dtype: int64

# %%
df_train = pd.concat([X_train_smote, y_train_smote], axis = 1).reset_index(drop = True)

# %% [markdown]
# * Ya se tiene un conjunto de entrenamiento y otro de pruebas
# * Ambos están normalizados con MaxMin
# * Para el conjunto de pruebas se balancearon las clases con un SMOTE
#
# - Ya se puede entrenar modelos con el conjunto de entrenamiento
# - El conjunto desbalanceado de pruebas ya se puede usar para evaluación al final

# %%
df_train.to_csv('../data/df_train.csv', index=False)
df_test.to_csv('../data/df_test.csv', index=False)
