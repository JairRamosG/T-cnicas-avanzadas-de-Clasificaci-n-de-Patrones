# %%
import pandas as pd

# %%
path_positiva_1 = 'Clase_positiva_1'
path_positiva_2 = 'Clase_positiva_0'

# %%
positiva_1 = pd.read_csv(path_positiva_1)
positiva_1.head()
# Out:
#    Accuracy  Balanced Accuracy  Error Rate  F1-Score  MCC  Precision  \
# 0  0.444444           0.222222    0.555556  0.615385  0.0        1.0
# 1  0.666667           0.333333    0.333333  0.800000  0.0        1.0
# 2  0.777778           0.388889    0.222222  0.875000  0.0        1.0
# 3  0.833333           0.416667    0.166667  0.909091  0.0        1.0
# 4  0.861111           0.430556    0.138889  0.925373  0.0        1.0
#
#      Recall  Specificity
# 0  0.444444          0.0
# 1  0.666667          0.0
# 2  0.777778          0.0
# 3  0.833333          0.0
# 4  0.861111          0.0

# %%
positiva_0 = pd.read_csv(path_positiva_1)
positiva_0.head()
# Out:
#    Accuracy  Balanced Accuracy  Error Rate  F1-Score  MCC  Precision  \
# 0  0.444444           0.222222    0.555556  0.615385  0.0        1.0
# 1  0.666667           0.333333    0.333333  0.800000  0.0        1.0
# 2  0.777778           0.388889    0.222222  0.875000  0.0        1.0
# 3  0.833333           0.416667    0.166667  0.909091  0.0        1.0
# 4  0.861111           0.430556    0.138889  0.925373  0.0        1.0
#
#      Recall  Specificity
# 0  0.444444          0.0
# 1  0.666667          0.0
# 2  0.777778          0.0
# 3  0.833333          0.0
# 4  0.861111          0.0
